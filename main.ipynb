# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from sklearn import preprocessing
from diffusers import UNet1DModel, DDPMScheduler, DDIMScheduler
from tqdm.auto import tqdm
from torch.utils.data import DataLoader, Dataset
from torch.nn import functional as F

# %%
def get_rms(records, multi_channels):
    if multi_channels == 1:
        n = records.shape[0]
        rms = 0
        for i in range(n):
            rms_t = np.sum([records[i]**2]/len(records[i]))
            rms += rms_t
        return rms/n
    
    if multi_channels == 0:
        rms = np.sum([records**2])/ len(records)
        return rms

def snr(signal, noisy):
    snr = 10 * np.log10(signal/noisy)
    return snr

# %%
def random_signal(signal, comb):
    res = []

    for i in range(comb):
        rand_num = np.random.permutation(signal.shape[0])
        shuffled_dataset = signal[rand_num, :]
        shuffled_dataset = shuffled_dataset.reshape(signal.shape[0], signal.shape[1])
        res.append(shuffled_dataset)
    
    random_result = np.array(res)

    return random_result

# %%
def prepare_data(comb):
    eeg_data = np.load('./data/EEG_all_epochs.npy')
    noise_data = np.load('./data/EMG_all_epochs.npy')

    eeg_random = np.squeeze(random_signal(signal=eeg_data, comb=1))
    noise_random = np.squeeze(random_signal(signal=noise_data, comb=1))

    reuse_num = noise_random.shape[0] - eeg_random.shape[0]
    eeg_reuse = eeg_random[0: reuse_num, :]
    eeg_random = np.vstack([eeg_reuse, eeg_random])
    print(f'EEG shape after crop and resuse to match EMG samples: {eeg_random.shape[0]}')

    t = noise_random.shape[1]
    train_num = round(eeg_random.shape[0] * 0.9)
    test_num = round(eeg_random.shape[0] - train_num)

    train_eeg = eeg_random[0: train_num, :]
    test_eeg = eeg_random[train_num: train_num + test_num,:]

    train_noise = noise_random[0: train_num, :]
    test_noise = noise_random[train_num: train_num+test_num, :]

    EEG_train = random_signal(signal=train_eeg, comb=comb).reshape(comb * train_eeg.shape[0],t)
    NOISE_train = random_signal(signal=train_noise, comb=comb).reshape(comb * train_noise.shape[0], t)

    EEG_test = random_signal(signal=test_eeg, comb=comb).reshape(comb * test_eeg.shape[0],t)
    NOISE_test = random_signal(signal=test_noise, comb=comb).reshape(comb * test_noise.shape[0], t)

    print(f"train data clean shape: {EEG_train.shape}")
    print(f"train data noise shape: {NOISE_train.shape}")

    sn_train = []
    eeg_train = []
    all_sn_test = []
    all_eeg_test = []

    SNR_train_dB = np.random.uniform(-7.0, 3.0, (EEG_train.shape[0]))
    print(SNR_train_dB.shape)
    SNR_train = np.sqrt(10**(0.1*(SNR_train_dB)))


    for i in range(EEG_train.shape[0]):
        noise = preprocessing.scale(NOISE_train[i])
        EEG = preprocessing.scale(EEG_train[i])

        alpha = get_rms(EEG, 0) / (get_rms(noise, 0 ) * SNR_train[i])
        noise *= alpha
        signal_noise = EEG + noise

        sn_train.append(signal_noise)
        eeg_train.append(EEG)
    
    SNR_test_dB = np.linspace(-7.0, 3.0, num=(11))
    SNR_test = np.sqrt(10 ** (0.1 * SNR_test_dB))

    for i in range(11):
        sn_test = []
        eeg_test = []
        for k in range(EEG_test.shape[0]):
            noise = preprocessing.scale(NOISE_test[k])
            EEG = preprocessing.scale(EEG_test[k])

            alpha = get_rms(EEG,0) / (get_rms(noise, 0) * SNR_test[i])
            noise *= alpha
            signal_noise = EEG + noise

            sn_test.append(signal_noise)
            eeg_test.append(EEG)
        
        sn_test = np.array(sn_test)
        eeg_test = np.array(eeg_test)

        all_sn_test.append(sn_test)
        all_eeg_test.append(eeg_test)
    
    X_train = np.array(sn_train)
    y_train = np.array(eeg_train)

    X_test = np.array(all_sn_test)
    y_test = np.array(all_eeg_test)

    X_train = np.expand_dims(X_train, axis=1)
    y_train = np.expand_dims(y_train, axis=1)

    X_test = np.expand_dims(X_test, axis=2)
    y_test = np.expand_dims(y_test, axis=2)

    print(X_train.shape, y_train.shape)
    print(X_test.shape, y_test.shape)

    return [X_train, y_train, X_test, y_test]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
X_train, y_train, X_test, y_test = prepare_data(11)
# Out:
# EEG shape after crop and resuse to match EMG samples: 5598
# train data clean shape: (55418, 512)
# train data noise shape: (55418, 512)
# (55418,)
# (55418, 1, 512) (55418, 1, 512)
# (11, 6160, 1, 512) (11, 6160, 1, 512)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size = 0.1, random_state=42
)

# %%
X_train = X_train.astype(np.float32)
y_train = y_train.astype(np.float32)
X_val = X_val.astype(np.float32)
y_val = y_val.astype(np.float32)

# %%
print(X_val.shape, y_val.shape)
# Out:
# (5542, 1, 512) (5542, 1, 512)

# %%
X_train, y_train = torch.from_numpy(X_train), torch.from_numpy(y_train)
X_val, y_val = torch.from_numpy(X_val), torch.from_numpy(y_val)
print(type(X_train), type(y_train))
print(X_train.shape)
print(type(X_val), type(y_val))
print(X_val.shape)
# X_train.to(device), y_train.to(device)
# Out:
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([49876, 1, 512])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([5542, 1, 512])

# %%
class EEgDataSet(Dataset):
    def __init__(self, X_noisy: torch.tensor, y_clean: torch.tensor):
        self.xn = X_noisy.float()
        self.yn = y_clean.float()
    
    def __len__(self):
        return self.xn.shape[0]
    
    def __getitem__(self, i):
        return self.xn[i], self.yn[i]

# %%
model = UNet1DModel(
    sample_size=512,
    in_channels=2,
    out_channels=1,
    layers_per_block=3,
    block_out_channels=(64,128,256),
    down_block_types=(
        "DownBlock1D",
        "AttnDownBlock1D",
        "DownBlock1D",
    ),
    up_block_types=(
        "UpBlock1D",
        "AttnUpBlock1D",
        "UpBlock1D",
    ),
)
model.to(device)
model.parameters
# Out:
# <bound method Module.parameters of UNet1DModel(
#   (time_proj): GaussianFourierProjection()
#   (down_blocks): ModuleList(
#     (0): DownBlock1D(
#       (down): Downsample1d()
#       (resnets): ModuleList(
#         (0): ResConvBlock(
#           (conv_skip): Conv1d(2, 64, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(2, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (1-2): 2 x ResConvBlock(
#           (conv_1): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#       )
#     )
#     (1): AttnDownBlock1D(
#       (down): Downsample1d()
#       (attentions): ModuleList(
#         (0-2): 3 x SelfAttention1d(
#           (group_norm): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (query): Linear(in_features=128, out_features=128, bias=True)
#           (key): Linear(in_features=128, out_features=128, bias=True)
#           (value): Linear(in_features=128, out_features=128, bias=True)
#           (proj_attn): Linear(in_features=128, out_features=128, bias=True)
#           (dropout): Dropout(p=0.0, inplace=True)
#         )
#       )
#       (resnets): ModuleList(
#         (0): ResConvBlock(
#           (conv_skip): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(64, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (1-2): 2 x ResConvBlock(
#           (conv_1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#       )
#     )
#     (2): DownBlock1D(
#       (down): Downsample1d()
#       (resnets): ModuleList(
#         (0): ResConvBlock(
#           (conv_skip): Conv1d(128, 256, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(128, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (1-2): 2 x ResConvBlock(
#           (conv_1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#       )
#     )
#   )
#   (up_blocks): ModuleList(
#     (0): UpBlock1D(
#       (resnets): ModuleList(
#         (0): ResConvBlock(
#           (conv_skip): Conv1d(512, 256, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(512, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (1): ResConvBlock(
#           (conv_1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (2): ResConvBlock(
#           (conv_skip): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 256, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(256, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#       )
#       (up): Upsample1d()
#     )
#     (1): AttnUpBlock1D(
#       (attentions): ModuleList(
#         (0-2): 3 x SelfAttention1d(
#           (group_norm): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (proj_attn): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.0, inplace=True)
#         )
#       )
#       (resnets): ModuleList(
#         (0): ResConvBlock(
#           (conv_skip): Conv1d(256, 64, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(256, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (1-2): 2 x ResConvBlock(
#           (conv_1): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#       )
#       (up): Upsample1d()
#     )
#     (2): UpBlock1D(
#       (resnets): ModuleList(
#         (0): ResConvBlock(
#           (conv_skip): Conv1d(128, 64, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(128, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (1): ResConvBlock(
#           (conv_1): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#         (2): ResConvBlock(
#           (conv_skip): Conv1d(64, 1, kernel_size=(1,), stride=(1,), bias=False)
#           (conv_1): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_1): GroupNorm(1, 64, eps=1e-05, affine=True)
#           (gelu_1): GELU(approximate='none')
#           (conv_2): Conv1d(64, 1, kernel_size=(5,), stride=(1,), padding=(2,))
#           (group_norm_2): GroupNorm(1, 1, eps=1e-05, affine=True)
#           (gelu_2): GELU(approximate='none')
#         )
#       )
#       (up): Upsample1d()
#     )
#   )
#   (mid_block): UNetMidBlock1D(
#     (down): Downsample1d()
#     (up): Upsample1d()
#     (attentions): ModuleList(
#       (0-5): 6 x SelfAttention1d(
#         (group_norm): GroupNorm(1, 256, eps=1e-05, affine=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (proj_attn): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.0, inplace=True)
#       )
#     )
#     (resnets): ModuleList(
#       (0-5): 6 x ResConvBlock(
#         (conv_1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#         (group_norm_1): GroupNorm(1, 256, eps=1e-05, affine=True)
#         (gelu_1): GELU(approximate='none')
#         (conv_2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#         (group_norm_2): GroupNorm(1, 256, eps=1e-05, affine=True)
#         (gelu_2): GELU(approximate='none')
#       )
#     )
#   )
# )>

# %%
class Conditioner(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, hidden=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_channels, hidden, kernel_size=7, padding=3),
            nn.GroupNorm(8, hidden),
            nn.SiLU(),
            nn.Conv1d(hidden, out_channels, kernel_size=3, padding=1)
        )
    
    def forward(self,x):
        return self.net(x)

cond_net = Conditioner().to(device)

# %%
scheduler = DDPMScheduler(
    num_train_timesteps=400,
    beta_schedule="linear"
)

# scheduler = DDPMScheduler(
#     num_train_timesteps=1000,
#     beta_schedule="linear"
# )

# %%
from torch import amp
from torch.optim.lr_scheduler import CosineAnnealingLR

def train(model, scheduler, X_train, y_train, X_val, y_val,
           *, epochs=10, batch_size=512, lr=2e-4,
           wd=1e-5, grad_clip=1.0, cond_net):
    data = EEgDataSet(X_train, y_train)
    val_data = EEgDataSet(X_val, y_val)

    dl = DataLoader(data, 
                    batch_size=batch_size,
                    shuffle=True,
                    drop_last=True,
                    pin_memory=True)
    
    val_dl = DataLoader(val_data, 
                batch_size=batch_size,
                shuffle=False,
                drop_last=True,
                pin_memory=True)
    
    optim = torch.optim.AdamW(list(model.parameters()) + list(cond_net.parameters()), lr=lr, weight_decay=wd)
    scalar = amp.GradScaler(device=device)

    warmup_epochs = 5
    lr_sched = CosineAnnealingLR(optim, T_max=epochs-warmup_epochs, eta_min=1e-5)
    model.train()

    for e in range(1, epochs + 1):

        if e <= warmup_epochs:
            warm_lr = lr * e/warmup_epochs
            for pg in optim.param_groups:
                pg["lr"] = warm_lr

        total = 0.0
        n = 0
        val_total = 0.0
        val_n = 0

        for x_noisy, x_clean in dl:
            x_noisy = x_noisy.to(device, non_blocking=True).float()
            x_clean = x_clean.to(device, non_blocking=True).float()

            B = x_clean.size(0)
            t = torch.randint(0, scheduler.config.num_train_timesteps, (B, ), device=device).long()
            noise = torch.randn_like(x_clean)
            x_t = scheduler.add_noise(x_clean, noise,t)

            x_in = torch.cat([x_t, cond_net(x_noisy)], dim=1)
            with amp.autocast(device_type=device, dtype=torch.float16):
                pred_noise = model(x_in, t).sample
                loss = F.mse_loss(pred_noise, noise)

            optim.zero_grad(set_to_none=True)
            scalar.scale(loss).backward()
            if grad_clip:
                scalar.unscale_(optim)
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            scalar.step(optim)
            scalar.update()

            total += loss.item() * B

            n += B
        
        if e > warmup_epochs:
            lr_sched.step()
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for x_noisy, x_clean in val_dl:
                x_noisy = x_noisy.to(device).float()
                x_clean = x_clean.to(device).float()

                B= x_clean.size(0)
                t = torch.randint(0, scheduler.config.num_train_timesteps, (B,), device=device).long()
                noise = torch.randn_like(x_clean)
                x_t = scheduler.add_noise(x_clean, noise, t)
                cond = cond_net(x_noisy)
                with amp.autocast(device_type=device, dtype=torch.float16):
                    pred_noise = model(torch.cat([x_t, cond], dim=1), t).sample
                    loss = F.mse_loss(pred_noise, noise)
                val_total += loss.item() * B
                val_n += B
        val_loss = val_total / val_n
        model.train()
        cond_net.train()
        print(f"epoch {e}: train loss = {total/n: .4f}, val_los = {val_loss:.4f}")

# %%
@torch.no_grad()
def denoise(model, scheduler, x_noisy, *, strength=0.25, num_inference_steps=50, cond_net):
    model.eval()
    cond_net.eval()
    x = x_noisy.float().to(device)

    scheduler.set_timesteps(num_inference_steps)
    t_start = int(max(1, min(num_inference_steps-1, round(strength * num_inference_steps))))
    timesteps = scheduler.timesteps[t_start:]
    start_t = scheduler.timesteps[t_start]

    outs = []
    for i in range(0, x.size(0), 128):
        X_noisy = x[i:i+128]
        noise = torch.randn_like(X_noisy)
        x_t = scheduler.add_noise(X_noisy, noise, start_t)
        c = cond_net(X_noisy)
        for t in timesteps:
            x_in = torch.cat([x_t, c], dim=1)
            eps = model(x_in, t).sample
            x_t = scheduler.step(eps, t, x_t).prev_sample
        
        outs.append(x_t.detach().cpu())
    return torch.cat(outs, dim=0)

# %%
def rrmse_time(yhat, y):
    num = torch.mean((yhat- y)**2, dim=-1).sqrt()
    den = torch.mean(y**2, dim=-1).sqrt() + 1e-8
    return (num/den).mean().item()

def cc (yhat, y):
    yhat = yhat - yhat.mean(dim=-1, keepdim=True)
    y = y - y.mean(dim=-1, keepdim=True)
    num = (yhat*y).sum(dim=-1)
    den = (yhat.norm(dim=-1)*y.norm(dim=-1) + 1e-8)

    return (num/den).mean().item()

# %%
train(model, scheduler, X_train, y_train, X_val, y_val, epochs=200, batch_size=512, lr=1e-3, wd=0, cond_net=cond_net)
# Out:
# epoch 1: train loss =  0.9777, val_los = 0.6787
# epoch 2: train loss =  0.6755, val_los = 0.6670
# epoch 3: train loss =  0.6622, val_los = 0.6622
# epoch 4: train loss =  0.6545, val_los = 0.6531
# epoch 5: train loss =  0.6549, val_los = 0.6537
# epoch 6: train loss =  0.6461, val_los = 0.6463
# epoch 7: train loss =  0.6432, val_los = 0.6415
# epoch 8: train loss =  0.6426, val_los = 0.6416
# epoch 9: train loss =  0.6414, val_los = 0.6435
# epoch 10: train loss =  0.6406, val_los = 0.6388
# epoch 11: train loss =  0.6409, val_los = 0.6431
# epoch 12: train loss =  0.6397, val_los = 0.6426
# epoch 13: train loss =  0.6384, val_los = 0.6429
# epoch 14: train loss =  0.6368, val_los = 0.6341
# epoch 15: train loss =  0.6344, val_los = 0.6359
# epoch 16: train loss =  0.6294, val_los = 0.6268
# epoch 17: train loss =  0.6251, val_los = 0.6225
# epoch 18: train loss =  0.6194, val_los = 0.6220
# epoch 19: train loss =  0.6142, val_los = 0.6144
# epoch 20: train loss =  0.6090, val_los = 0.6074
# epoch 21: train loss =  0.6037, val_los = 0.6010
# epoch 22: train loss =  0.5983, val_los = 0.5971
# epoch 23: train loss =  0.5945, val_los = 0.5928
# epoch 24: train loss =  0.5883, val_los = 0.5903
# epoch 25: train loss =  0.5855, val_los = 0.5867
# epoch 26: train loss =  0.5832, val_los = 0.5853
# epoch 27: train loss =  0.5802, val_los = 0.5776
# epoch 28: train loss =  0.5773, val_los = 0.5795
# epoch 29: train loss =  0.5742, val_los = 0.5755
# epoch 30: train loss =  0.5725, val_los = 0.5739
# epoch 31: train loss =  0.5697, val_los = 0.5704
# epoch 32: train loss =  0.5682, val_los = 0.5685
# epoch 33: train loss =  0.5670, val_los = 0.5704
# epoch 34: train loss =  0.5652, val_los = 0.5659
# epoch 35: train loss =  0.5642, val_los = 0.5668
# epoch 36: train loss =  0.5622, val_los = 0.5669
# epoch 37: train loss =  0.5604, val_los = 0.5636
# epoch 38: train loss =  0.5589, val_los = 0.5597
# epoch 39: train loss =  0.5584, val_los = 0.5603
# epoch 40: train loss =  0.5573, val_los = 0.5589
# epoch 41: train loss =  0.5568, val_los = 0.5557
# epoch 42: train loss =  0.5560, val_los = 0.5567
# epoch 43: train loss =  0.5550, val_los = 0.5575
# epoch 44: train loss =  0.5539, val_los = 0.5571
# epoch 45: train loss =  0.5532, val_los = 0.5548
# epoch 46: train loss =  0.5521, val_los = 0.5554
# epoch 47: train loss =  0.5518, val_los = 0.5539
# epoch 48: train loss =  0.5515, val_los = 0.5524
# epoch 49: train loss =  0.5495, val_los = 0.5523
# epoch 50: train loss =  0.5490, val_los = 0.5504
# epoch 51: train loss =  0.5494, val_los = 0.5515
# epoch 52: train loss =  0.5493, val_los = 0.5503
# epoch 53: train loss =  0.5484, val_los = 0.5508
# epoch 54: train loss =  0.5476, val_los = 0.5509
# epoch 55: train loss =  0.5464, val_los = 0.5518
# epoch 56: train loss =  0.5466, val_los = 0.5483
# epoch 57: train loss =  0.5465, val_los = 0.5501
# epoch 58: train loss =  0.5445, val_los = 0.5494
# epoch 59: train loss =  0.5450, val_los = 0.5479
# epoch 60: train loss =  0.5450, val_los = 0.5476
# epoch 61: train loss =  0.5440, val_los = 0.5446
# epoch 62: train loss =  0.5437, val_los = 0.5470
# epoch 63: train loss =  0.5433, val_los = 0.5470
# epoch 64: train loss =  0.5427, val_los = 0.5462
# epoch 65: train loss =  0.5424, val_los = 0.5448
# epoch 66: train loss =  0.5432, val_los = 0.5448
# epoch 67: train loss =  0.5422, val_los = 0.5441
# epoch 68: train loss =  0.5413, val_los = 0.5419
# epoch 69: train loss =  0.5421, val_los = 0.5427
# epoch 70: train loss =  0.5400, val_los = 0.5414
# epoch 71: train loss =  0.5409, val_los = 0.5405
# epoch 72: train loss =  0.5393, val_los = 0.5391
# epoch 73: train loss =  0.5394, val_los = 0.5404
# epoch 74: train loss =  0.5396, val_los = 0.5423
# epoch 75: train loss =  0.5396, val_los = 0.5415
# epoch 76: train loss =  0.5388, val_los = 0.5389
# epoch 77: train loss =  0.5384, val_los = 0.5416
# epoch 78: train loss =  0.5378, val_los = 0.5417
# epoch 79: train loss =  0.5383, val_los = 0.5401
# epoch 80: train loss =  0.5377, val_los = 0.5403
# epoch 81: train loss =  0.5379, val_los = 0.5398
# epoch 82: train loss =  0.5376, val_los = 0.5393
# epoch 83: train loss =  0.5367, val_los = 0.5384
# epoch 84: train loss =  0.5367, val_los = 0.5381
# epoch 85: train loss =  0.5364, val_los = 0.5377
# epoch 86: train loss =  0.5364, val_los = 0.5396
# epoch 87: train loss =  0.5357, val_los = 0.5383
# epoch 88: train loss =  0.5348, val_los = 0.5366
# epoch 89: train loss =  0.5345, val_los = 0.5369
# epoch 90: train loss =  0.5347, val_los = 0.5350
# epoch 91: train loss =  0.5345, val_los = 0.5373
# epoch 92: train loss =  0.5341, val_los = 0.5365
# epoch 93: train loss =  0.5344, val_los = 0.5367
# epoch 94: train loss =  0.5335, val_los = 0.5350
# epoch 95: train loss =  0.5330, val_los = 0.5359
# epoch 96: train loss =  0.5332, val_los = 0.5374
# epoch 97: train loss =  0.5325, val_los = 0.5357
# epoch 98: train loss =  0.5325, val_los = 0.5358
# epoch 99: train loss =  0.5327, val_los = 0.5366
# epoch 100: train loss =  0.5318, val_los = 0.5352
# epoch 101: train loss =  0.5320, val_los = 0.5344
# epoch 102: train loss =  0.5310, val_los = 0.5346
# epoch 103: train loss =  0.5309, val_los = 0.5330
# epoch 104: train loss =  0.5318, val_los = 0.5338
# epoch 105: train loss =  0.5307, val_los = 0.5321
# epoch 106: train loss =  0.5297, val_los = 0.5332
# epoch 107: train loss =  0.5310, val_los = 0.5326
# epoch 108: train loss =  0.5302, val_los = 0.5332
# epoch 109: train loss =  0.5303, val_los = 0.5338
# epoch 110: train loss =  0.5285, val_los = 0.5308
# epoch 111: train loss =  0.5295, val_los = 0.5321
# epoch 112: train loss =  0.5298, val_los = 0.5312
# epoch 113: train loss =  0.5283, val_los = 0.5301
# epoch 114: train loss =  0.5283, val_los = 0.5310
# epoch 115: train loss =  0.5279, val_los = 0.5312
# epoch 116: train loss =  0.5281, val_los = 0.5303
# epoch 117: train loss =  0.5284, val_los = 0.5309
# epoch 118: train loss =  0.5273, val_los = 0.5306
# epoch 119: train loss =  0.5274, val_los = 0.5284
# epoch 120: train loss =  0.5268, val_los = 0.5280
# epoch 121: train loss =  0.5273, val_los = 0.5288
# epoch 122: train loss =  0.5261, val_los = 0.5291
# epoch 123: train loss =  0.5260, val_los = 0.5279
# epoch 124: train loss =  0.5264, val_los = 0.5291
# epoch 125: train loss =  0.5259, val_los = 0.5277
# epoch 126: train loss =  0.5253, val_los = 0.5291
# epoch 127: train loss =  0.5258, val_los = 0.5274
# epoch 128: train loss =  0.5257, val_los = 0.5295
# epoch 129: train loss =  0.5253, val_los = 0.5269
# epoch 130: train loss =  0.5255, val_los = 0.5284
# epoch 131: train loss =  0.5245, val_los = 0.5256
# epoch 132: train loss =  0.5245, val_los = 0.5270
# epoch 133: train loss =  0.5244, val_los = 0.5261
# epoch 134: train loss =  0.5239, val_los = 0.5252
# epoch 135: train loss =  0.5237, val_los = 0.5257
# epoch 136: train loss =  0.5229, val_los = 0.5264
# epoch 137: train loss =  0.5233, val_los = 0.5257
# epoch 138: train loss =  0.5228, val_los = 0.5264
# epoch 139: train loss =  0.5228, val_los = 0.5242
# epoch 140: train loss =  0.5225, val_los = 0.5256
# epoch 141: train loss =  0.5226, val_los = 0.5242
# epoch 142: train loss =  0.5222, val_los = 0.5247
# epoch 143: train loss =  0.5210, val_los = 0.5239
# epoch 144: train loss =  0.5217, val_los = 0.5241
# epoch 145: train loss =  0.5216, val_los = 0.5237
# epoch 146: train loss =  0.5211, val_los = 0.5230
# epoch 147: train loss =  0.5213, val_los = 0.5234
# epoch 148: train loss =  0.5204, val_los = 0.5223
# epoch 149: train loss =  0.5207, val_los = 0.5240
# epoch 150: train loss =  0.5204, val_los = 0.5228
# epoch 151: train loss =  0.5202, val_los = 0.5223
# epoch 152: train loss =  0.5199, val_los = 0.5220
# epoch 153: train loss =  0.5194, val_los = 0.5229
# epoch 154: train loss =  0.5203, val_los = 0.5207
# epoch 155: train loss =  0.5197, val_los = 0.5232
# epoch 156: train loss =  0.5188, val_los = 0.5222
# epoch 157: train loss =  0.5188, val_los = 0.5218
# epoch 158: train loss =  0.5187, val_los = 0.5211
# epoch 159: train loss =  0.5187, val_los = 0.5200
# epoch 160: train loss =  0.5186, val_los = 0.5196
# epoch 161: train loss =  0.5183, val_los = 0.5199
# epoch 162: train loss =  0.5178, val_los = 0.5189
# epoch 163: train loss =  0.5175, val_los = 0.5201
# epoch 164: train loss =  0.5176, val_los = 0.5200
# epoch 165: train loss =  0.5171, val_los = 0.5206
# epoch 166: train loss =  0.5173, val_los = 0.5187
# epoch 167: train loss =  0.5166, val_los = 0.5192
# epoch 168: train loss =  0.5164, val_los = 0.5187
# epoch 169: train loss =  0.5167, val_los = 0.5185
# epoch 170: train loss =  0.5164, val_los = 0.5187
# epoch 171: train loss =  0.5163, val_los = 0.5179
# epoch 172: train loss =  0.5165, val_los = 0.5188
# epoch 173: train loss =  0.5163, val_los = 0.5199
# epoch 174: train loss =  0.5158, val_los = 0.5179
# epoch 175: train loss =  0.5155, val_los = 0.5190
# epoch 176: train loss =  0.5160, val_los = 0.5169
# epoch 177: train loss =  0.5157, val_los = 0.5164
# epoch 178: train loss =  0.5154, val_los = 0.5170
# epoch 179: train loss =  0.5151, val_los = 0.5175
# epoch 180: train loss =  0.5150, val_los = 0.5167
# epoch 181: train loss =  0.5147, val_los = 0.5181
# epoch 182: train loss =  0.5150, val_los = 0.5174
# epoch 183: train loss =  0.5143, val_los = 0.5176
# epoch 184: train loss =  0.5147, val_los = 0.5167
# epoch 185: train loss =  0.5141, val_los = 0.5171
# epoch 186: train loss =  0.5141, val_los = 0.5157
# epoch 187: train loss =  0.5145, val_los = 0.5160
# epoch 188: train loss =  0.5145, val_los = 0.5169
# epoch 189: train loss =  0.5140, val_los = 0.5173
# epoch 190: train loss =  0.5138, val_los = 0.5165
# epoch 191: train loss =  0.5136, val_los = 0.5174
# epoch 192: train loss =  0.5138, val_los = 0.5157
# epoch 193: train loss =  0.5140, val_los = 0.5164
# epoch 194: train loss =  0.5137, val_los = 0.5164
# epoch 195: train loss =  0.5136, val_los = 0.5168
# epoch 196: train loss =  0.5139, val_los = 0.5159
# epoch 197: train loss =  0.5139, val_los = 0.5174
# epoch 198: train loss =  0.5141, val_los = 0.5164
# epoch 199: train loss =  0.5135, val_los = 0.5155
# epoch 200: train loss =  0.5134, val_los = 0.5168

# %%
X_test_t = torch.from_numpy(X_test).to(device)
y_test_t = torch.from_numpy(y_test).to(device)

print(X_test_t[0].shape)
# Out:
# torch.Size([6160, 1, 512])

# %%
inference_scheduler = DDIMScheduler.from_config(scheduler.config)

# %%
best = None
for s in [0, 2, 5, 6, 8]:
    print(f"Testing for SNR: {-7+s}")
    y_ref = y_test_t[s].to(device)
    y_hat = denoise(model, inference_scheduler, X_test_t[s], strength=0.6, num_inference_steps=200, cond_net=cond_net)
    y_hat = y_hat.to(device)
    m = rrmse_time(y_hat, y_ref)
    c = cc(y_hat, y_ref)
    print(f"RRMSE_t={m:.4f}, CC={c:.4f}")
    best = (m, s) if best is None or m < best[0] else best

print("best strength:", best[1])
# Out:
# Testing for SNR: -5
# RRMSE_t=0.8821, CC=0.5267
# Testing for SNR: -3
# RRMSE_t=0.8290, CC=0.5835
# Testing for SNR: 0
# RRMSE_t=0.7638, CC=0.6506
# Testing for SNR: 1
# RRMSE_t=0.7458, CC=0.6686
# Testing for SNR: 3
# RRMSE_t=0.7176, CC=0.6963
# best strength: 8
